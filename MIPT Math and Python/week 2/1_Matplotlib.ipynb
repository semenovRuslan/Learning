# %% [markdown]
# # Introduction  Matplotlib

# %% [markdown]
# For graphics

# %%
# %matplotlib inline  # for displaying graph immediatelly

# %%
from matplotlib import pylab as plt

plt.plot([1, 2, 3, 4], [1, 4, 9, 16])
plt.show()

# %%
# set formula
import numpy as np

x=np.arange(-10,10,0.001)
y=np.sin(x)
plt.plot(x, y)
plt.show()
